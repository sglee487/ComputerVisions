# %%
import pytesseract
import matplotlib.pyplot as plt
import cv2

# %%
im = cv2.imread("korex.jpg")
plt.imshow(im)

# cv2.imshow("korex",im)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(im, lang='kor')
print(text)
# Out:
# 가나다라마바사
#
# 다람쥐 햇 바퀴 헌 바퀴
#
# 우가 무
#
# 있다
#
# 0모
#
# 위
#
# 뛰어놀
#
# 비요

# %%
im = cv2.imread("20200320_115232_HDRcrop.jpg")
plt.imshow(im)

# %%
text = pytesseract.image_to_string(im, lang='kor')
print(text)

# %%
img = cv2.GaussianBlur(im,(5,5),1)
plt.imshow(img)

# %%
text = pytesseract.image_to_string(im, lang='kor')
print(text)
