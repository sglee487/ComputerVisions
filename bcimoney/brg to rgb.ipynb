# %% [markdown]
# 출처: https://crmn.tistory.com/49 [크롬망간이 글 쓰는 공간]

# %%
import tensorflow as tf
import os
import numpy as np

# %%
import cv2

import matplotlib.pyplot as plt

image_1 = cv2.imread("./numbers/1.png")

image_1 = cv2.cvtColor(image_1, cv2.COLOR_BGR2RGB)

# 이 아래 부분은 그림을 화면에 출력하기 위한 부분으로, OpenCV 알고리즘과는 상관이 없습니다.

plt.imshow(image_1[:,:,0], interpolation='bicubic')

plt.show()
